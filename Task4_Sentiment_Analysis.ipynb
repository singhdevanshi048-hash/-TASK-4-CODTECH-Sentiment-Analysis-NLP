# %% [markdown]
# # 📊 CODTECH Internship - Task 4
#
# ## Sentiment Analysis using Natural Language Processing (NLP)
#
# ### 👩‍💻 Developed By
# **Devanshi Singh**
#
# ### 🎯 Objective
# The objective of this project is to perform Sentiment Analysis on customer reviews using Natural Language Processing (NLP) and Machine Learning techniques. The model predicts whether a review is Positive or Negative.
#
# ---
#
# ### 🛠 Technologies Used
# - Python
# - Pandas
# - Scikit-Learn
# - TF-IDF Vectorizer
# - Logistic Regression
# - Joblib
# - Streamlit

# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

import joblib

# %% [markdown]
# # Dataset Loading
#
# In this project we use Amazon, IMDb and Yelp review datasets for sentiment analysis.
